# %%
import pandas as pd

df = pd.read_csv('data_test1.csv')

df.describe()
# Out:
#        loại nhà đất       địa chỉ            giá     diện tích        giá/m2  \
# count  20447.000000  20447.000000   20447.000000  20447.000000  20447.000000
# mean       2.836064     13.312613   16960.379814    130.664988    151.992878
# std        2.220754      6.697470   30265.384590    153.257208    271.968265
# min        0.000000      0.000000       7.500000      1.000000      1.020000
# 25%        2.000000      8.000000    5600.000000     61.500000     67.550000
# 50%        2.000000     13.000000    9300.000000     86.000000    105.260000
# 75%        4.000000     20.000000   15500.000000    123.500000    159.620000
# max        7.000000     23.000000  955330.000000    991.000000  23000.000000
#
#            mặt tiền     phòng ngủ       pháp lý      tọa độ x      tọa độ y  \
# count  14277.000000  13216.000000  18031.000000  2.044700e+04  2.044700e+04
# mean       7.845638      3.720642      1.101880  1.099098e+10  1.066338e+11
# ...
